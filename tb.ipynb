# %%
from pynq import Overlay
Proc_RISCV = Overlay('/home/xilinx/pynq/overlays/design_RISCVEIRB/design_RISCVEIRB.bit')
Proc_RISCV?
RISCV = Proc_RISCV.My_RISCVEIRB_IP_0 
RISCV?
from RISCVEIRB_Controller import *
Controller = RISCVEIRB_Controller()

# %%
Controller.tb_all(print_opt = True);
# Out:
# TB :  ./tb/tb0
#
# Instruction Memory Write Process
#
# Octet value Write for current Instruction 0xa00093 at address 0 : [ 0x0 ; 0xa0 ; 0x0 ; 0x93 ]
# Octet value Write for current Instruction 0x102023 at address 1 : [ 0x0 ; 0x10 ; 0x20 ; 0x23 ]
# Program Counter (PC) value :  0 ( 0 ), Current Instruction : 0xa00093 , New Address Instruction : 4
# Mem Data Address value :  10 , Data In :  0x0 , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  0 ( 0 ), Current Instruction : 0xa00093 , New Address Instruction : 4
# Mem Data Address value :  10 , Data In :  0x0 , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  0 ( 0 ), Current Instruction : 0xa00093 , New Address Instruction : 4
# Mem Data Address value :  10 , Data In :  0x0 , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : ExeOpimm
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  4 ( 1 ), Current Instruction : 0x102023 , New Address Instruction : 8
# Mem Data Address value :  0 , Data In :  0xa , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  4 ( 1 ), Current Instruction : 0x102023 , New Address Instruction : 8
# Mem Data Address value :  0 , Data In :  0xa , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  4 ( 1 ), Current Instruction : 0x102023 , New Address Instruction : 8
# Mem Data Address value :  0 , Data In :  0xa , Data Out: 0xa
# UAL operation:  0b1 -> 1
# Current State Machine is : ExeAddr
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  4 ( 1 ), Current Instruction : 0x102023 , New Address Instruction : 8
# Mem Data Address value :  0 , Data In :  0xa , Data Out: 0xa
# UAL operation:  0b1 -> 1
# Current State Machine is : ExeWrite
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  8 ( 2 ), Current Instruction : 0x0 , New Address Instruction : 12
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  8 ( 2 ), Current Instruction : 0x0 , New Address Instruction : 12
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  8 ( 2 ), Current Instruction : 0x0 , New Address Instruction : 12
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  12 ( 3 ), Current Instruction : 0x0 , New Address Instruction : 16
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  12 ( 3 ), Current Instruction : 0x0 , New Address Instruction : 16
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  12 ( 3 ), Current Instruction : 0x0 , New Address Instruction : 16
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  16 ( 4 ), Current Instruction : 0x0 , New Address Instruction : 20
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  16 ( 4 ), Current Instruction : 0x0 , New Address Instruction : 20
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  16 ( 4 ), Current Instruction : 0x0 , New Address Instruction : 20
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  20 ( 5 ), Current Instruction : 0x0 , New Address Instruction : 24
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  20 ( 5 ), Current Instruction : 0x0 , New Address Instruction : 24
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  20 ( 5 ), Current Instruction : 0x0 , New Address Instruction : 24
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  24 ( 6 ), Current Instruction : 0x0 , New Address Instruction : 28
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  24 ( 6 ), Current Instruction : 0x0 , New Address Instruction : 28
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  24 ( 6 ), Current Instruction : 0x0 , New Address Instruction : 28
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  28 ( 7 ), Current Instruction : 0x0 , New Address Instruction : 32
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  28 ( 7 ), Current Instruction : 0x0 , New Address Instruction : 32
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  28 ( 7 ), Current Instruction : 0x0 , New Address Instruction : 32
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  32 ( 8 ), Current Instruction : 0x0 , New Address Instruction : 36
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  32 ( 8 ), Current Instruction : 0x0 , New Address Instruction : 36
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  32 ( 8 ), Current Instruction : 0x0 , New Address Instruction : 36
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  36 ( 9 ), Current Instruction : 0x0 , New Address Instruction : 40
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  36 ( 9 ), Current Instruction : 0x0 , New Address Instruction : 40
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  36 ( 9 ), Current Instruction : 0x0 , New Address Instruction : 40
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  40 ( 10 ), Current Instruction : 0x0 , New Address Instruction : 44
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  40 ( 10 ), Current Instruction : 0x0 , New Address Instruction : 44
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  40 ( 10 ), Current Instruction : 0x0 , New Address Instruction : 44
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  44 ( 11 ), Current Instruction : 0x0 , New Address Instruction : 48
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  44 ( 11 ), Current Instruction : 0x0 , New Address Instruction : 48
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  44 ( 11 ), Current Instruction : 0x0 , New Address Instruction : 48
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  48 ( 12 ), Current Instruction : 0x0 , New Address Instruction : 52
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  48 ( 12 ), Current Instruction : 0x0 , New Address Instruction : 52
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  48 ( 12 ), Current Instruction : 0x0 , New Address Instruction : 52
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  52 ( 13 ), Current Instruction : 0x0 , New Address Instruction : 56
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  52 ( 13 ), Current Instruction : 0x0 , New Address Instruction : 56
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  52 ( 13 ), Current Instruction : 0x0 , New Address Instruction : 56
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  56 ( 14 ), Current Instruction : 0x0 , New Address Instruction : 60
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  56 ( 14 ), Current Instruction : 0x0 , New Address Instruction : 60
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  56 ( 14 ), Current Instruction : 0x0 , New Address Instruction : 60
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  60 ( 15 ), Current Instruction : 0x0 , New Address Instruction : 64
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  60 ( 15 ), Current Instruction : 0x0 , New Address Instruction : 64
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  60 ( 15 ), Current Instruction : 0x0 , New Address Instruction : 64
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  64 ( 16 ), Current Instruction : 0x0 , New Address Instruction : 68
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  64 ( 16 ), Current Instruction : 0x0 , New Address Instruction : 68
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  64 ( 16 ), Current Instruction : 0x0 , New Address Instruction : 68
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  68 ( 17 ), Current Instruction : 0x0 , New Address Instruction : 72
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  68 ( 17 ), Current Instruction : 0x0 , New Address Instruction : 72
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  68 ( 17 ), Current Instruction : 0x0 , New Address Instruction : 72
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  72 ( 18 ), Current Instruction : 0x0 , New Address Instruction : 76
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  72 ( 18 ), Current Instruction : 0x0 , New Address Instruction : 76
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  72 ( 18 ), Current Instruction : 0x0 , New Address Instruction : 76
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  76 ( 19 ), Current Instruction : 0x0 , New Address Instruction : 80
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  76 ( 19 ), Current Instruction : 0x0 , New Address Instruction : 80
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  76 ( 19 ), Current Instruction : 0x0 , New Address Instruction : 80
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  80 ( 20 ), Current Instruction : 0x0 , New Address Instruction : 84
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  80 ( 20 ), Current Instruction : 0x0 , New Address Instruction : 84
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  80 ( 20 ), Current Instruction : 0x0 , New Address Instruction : 84
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  84 ( 21 ), Current Instruction : 0x0 , New Address Instruction : 88
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  84 ( 21 ), Current Instruction : 0x0 , New Address Instruction : 88
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  84 ( 21 ), Current Instruction : 0x0 , New Address Instruction : 88
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  88 ( 22 ), Current Instruction : 0x0 , New Address Instruction : 92
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  88 ( 22 ), Current Instruction : 0x0 , New Address Instruction : 92
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  88 ( 22 ), Current Instruction : 0x0 , New Address Instruction : 92
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  92 ( 23 ), Current Instruction : 0x0 , New Address Instruction : 96
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  92 ( 23 ), Current Instruction : 0x0 , New Address Instruction : 96
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  92 ( 23 ), Current Instruction : 0x0 , New Address Instruction : 96
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  96 ( 24 ), Current Instruction : 0x0 , New Address Instruction : 100
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  96 ( 24 ), Current Instruction : 0x0 , New Address Instruction : 100
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  96 ( 24 ), Current Instruction : 0x0 , New Address Instruction : 100
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  100 ( 25 ), Current Instruction : 0x0 , New Address Instruction : 104
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  100 ( 25 ), Current Instruction : 0x0 , New Address Instruction : 104
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  100 ( 25 ), Current Instruction : 0x0 , New Address Instruction : 104
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  104 ( 26 ), Current Instruction : 0x0 , New Address Instruction : 108
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  104 ( 26 ), Current Instruction : 0x0 , New Address Instruction : 108
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  104 ( 26 ), Current Instruction : 0x0 , New Address Instruction : 108
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  108 ( 27 ), Current Instruction : 0x0 , New Address Instruction : 112
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  108 ( 27 ), Current Instruction : 0x0 , New Address Instruction : 112
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  108 ( 27 ), Current Instruction : 0x0 , New Address Instruction : 112
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  112 ( 28 ), Current Instruction : 0x0 , New Address Instruction : 116
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  112 ( 28 ), Current Instruction : 0x0 , New Address Instruction : 116
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  112 ( 28 ), Current Instruction : 0x0 , New Address Instruction : 116
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  116 ( 29 ), Current Instruction : 0x0 , New Address Instruction : 120
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  116 ( 29 ), Current Instruction : 0x0 , New Address Instruction : 120
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  116 ( 29 ), Current Instruction : 0x0 , New Address Instruction : 120
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  120 ( 30 ), Current Instruction : 0x0 , New Address Instruction : 124
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  120 ( 30 ), Current Instruction : 0x0 , New Address Instruction : 124
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  120 ( 30 ), Current Instruction : 0x0 , New Address Instruction : 124
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  124 ( 31 ), Current Instruction : 0x0 , New Address Instruction : 128
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  124 ( 31 ), Current Instruction : 0x0 , New Address Instruction : 128
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  124 ( 31 ), Current Instruction : 0x0 , New Address Instruction : 128
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  128 ( 32 ), Current Instruction : 0x0 , New Address Instruction : 132
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  128 ( 32 ), Current Instruction : 0x0 , New Address Instruction : 132
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  128 ( 32 ), Current Instruction : 0x0 , New Address Instruction : 132
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  132 ( 33 ), Current Instruction : 0x0 , New Address Instruction : 136
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  132 ( 33 ), Current Instruction : 0x0 , New Address Instruction : 136
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  132 ( 33 ), Current Instruction : 0x0 , New Address Instruction : 136
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  136 ( 34 ), Current Instruction : 0x0 , New Address Instruction : 140
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  136 ( 34 ), Current Instruction : 0x0 , New Address Instruction : 140
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  136 ( 34 ), Current Instruction : 0x0 , New Address Instruction : 140
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  140 ( 35 ), Current Instruction : 0x0 , New Address Instruction : 144
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  140 ( 35 ), Current Instruction : 0x0 , New Address Instruction : 144
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  140 ( 35 ), Current Instruction : 0x0 , New Address Instruction : 144
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  144 ( 36 ), Current Instruction : 0x0 , New Address Instruction : 148
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  144 ( 36 ), Current Instruction : 0x0 , New Address Instruction : 148
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  144 ( 36 ), Current Instruction : 0x0 , New Address Instruction : 148
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  148 ( 37 ), Current Instruction : 0x0 , New Address Instruction : 152
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  148 ( 37 ), Current Instruction : 0x0 , New Address Instruction : 152
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  148 ( 37 ), Current Instruction : 0x0 , New Address Instruction : 152
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  152 ( 38 ), Current Instruction : 0x0 , New Address Instruction : 156
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  152 ( 38 ), Current Instruction : 0x0 , New Address Instruction : 156
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  152 ( 38 ), Current Instruction : 0x0 , New Address Instruction : 156
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  156 ( 39 ), Current Instruction : 0x0 , New Address Instruction : 160
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  156 ( 39 ), Current Instruction : 0x0 , New Address Instruction : 160
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  156 ( 39 ), Current Instruction : 0x0 , New Address Instruction : 160
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  160 ( 40 ), Current Instruction : 0x0 , New Address Instruction : 164
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  160 ( 40 ), Current Instruction : 0x0 , New Address Instruction : 164
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  160 ( 40 ), Current Instruction : 0x0 , New Address Instruction : 164
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  164 ( 41 ), Current Instruction : 0x0 , New Address Instruction : 168
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  164 ( 41 ), Current Instruction : 0x0 , New Address Instruction : 168
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  164 ( 41 ), Current Instruction : 0x0 , New Address Instruction : 168
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  168 ( 42 ), Current Instruction : 0x0 , New Address Instruction : 172
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  168 ( 42 ), Current Instruction : 0x0 , New Address Instruction : 172
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  168 ( 42 ), Current Instruction : 0x0 , New Address Instruction : 172
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  172 ( 43 ), Current Instruction : 0x0 , New Address Instruction : 176
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  172 ( 43 ), Current Instruction : 0x0 , New Address Instruction : 176
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  172 ( 43 ), Current Instruction : 0x0 , New Address Instruction : 176
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  176 ( 44 ), Current Instruction : 0x0 , New Address Instruction : 180
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  176 ( 44 ), Current Instruction : 0x0 , New Address Instruction : 180
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  176 ( 44 ), Current Instruction : 0x0 , New Address Instruction : 180
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  180 ( 45 ), Current Instruction : 0x0 , New Address Instruction : 184
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  180 ( 45 ), Current Instruction : 0x0 , New Address Instruction : 184
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  180 ( 45 ), Current Instruction : 0x0 , New Address Instruction : 184
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  184 ( 46 ), Current Instruction : 0x0 , New Address Instruction : 188
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  184 ( 46 ), Current Instruction : 0x0 , New Address Instruction : 188
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  184 ( 46 ), Current Instruction : 0x0 , New Address Instruction : 188
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  188 ( 47 ), Current Instruction : 0x0 , New Address Instruction : 192
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  188 ( 47 ), Current Instruction : 0x0 , New Address Instruction : 192
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  188 ( 47 ), Current Instruction : 0x0 , New Address Instruction : 192
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  192 ( 48 ), Current Instruction : 0x0 , New Address Instruction : 196
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  192 ( 48 ), Current Instruction : 0x0 , New Address Instruction : 196
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  192 ( 48 ), Current Instruction : 0x0 , New Address Instruction : 196
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  196 ( 49 ), Current Instruction : 0x0 , New Address Instruction : 200
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  196 ( 49 ), Current Instruction : 0x0 , New Address Instruction : 200
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  196 ( 49 ), Current Instruction : 0x0 , New Address Instruction : 200
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  200 ( 50 ), Current Instruction : 0x0 , New Address Instruction : 204
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  200 ( 50 ), Current Instruction : 0x0 , New Address Instruction : 204
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  200 ( 50 ), Current Instruction : 0x0 , New Address Instruction : 204
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  204 ( 51 ), Current Instruction : 0x0 , New Address Instruction : 208
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  204 ( 51 ), Current Instruction : 0x0 , New Address Instruction : 208
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  204 ( 51 ), Current Instruction : 0x0 , New Address Instruction : 208
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  208 ( 52 ), Current Instruction : 0x0 , New Address Instruction : 212
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  208 ( 52 ), Current Instruction : 0x0 , New Address Instruction : 212
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  208 ( 52 ), Current Instruction : 0x0 , New Address Instruction : 212
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  212 ( 53 ), Current Instruction : 0x0 , New Address Instruction : 216
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  212 ( 53 ), Current Instruction : 0x0 , New Address Instruction : 216
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  212 ( 53 ), Current Instruction : 0x0 , New Address Instruction : 216
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  216 ( 54 ), Current Instruction : 0x0 , New Address Instruction : 220
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  216 ( 54 ), Current Instruction : 0x0 , New Address Instruction : 220
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  216 ( 54 ), Current Instruction : 0x0 , New Address Instruction : 220
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  220 ( 55 ), Current Instruction : 0x0 , New Address Instruction : 224
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  220 ( 55 ), Current Instruction : 0x0 , New Address Instruction : 224
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  220 ( 55 ), Current Instruction : 0x0 , New Address Instruction : 224
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  224 ( 56 ), Current Instruction : 0x0 , New Address Instruction : 228
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  224 ( 56 ), Current Instruction : 0x0 , New Address Instruction : 228
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  224 ( 56 ), Current Instruction : 0x0 , New Address Instruction : 228
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  228 ( 57 ), Current Instruction : 0x0 , New Address Instruction : 232
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  228 ( 57 ), Current Instruction : 0x0 , New Address Instruction : 232
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  228 ( 57 ), Current Instruction : 0x0 , New Address Instruction : 232
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  232 ( 58 ), Current Instruction : 0x0 , New Address Instruction : 236
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  232 ( 58 ), Current Instruction : 0x0 , New Address Instruction : 236
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  232 ( 58 ), Current Instruction : 0x0 , New Address Instruction : 236
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0xa
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeNop
# Data in UT for Load Instruction 0x0 , 0b0
#
# ...
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJalr2
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  308 ( 77 ), Current Instruction : 0x6f , New Address Instruction : 312
# Mem Data Address value :  0 , Data In :  0x0 , Data Out: 0x5
# UAL operation:  0b0 -> 0
# Current State Machine is : ExeJal
# Data in UT for Load Instruction 0x0 , 0b0
#
#
# Instruction Memory Read Process
#
# MEM( 0 ) =  0xf
# MEM( 1 ) =  0x5
# MEM( 2 ) =  0xf
# MEM( 3 ) =  0xf
# MEM( 4 ) =  0x0
# MEM( 5 ) =  0x1400
# MEM( 6 ) =  0x0
# MEM( 7 ) =  0x0
# MEM( 8 ) =  0x1
# MEM( 9 ) =  0x1
# MEM( 10 ) =  0x5
# MEM( 11 ) =  0xa
# MEM( 12 ) =  0xf
# MEM( 13 ) =  0x5
# MEM( 14 ) =  0xa
# MEM( 15 ) =  0x2
# MEM( 16 ) =  0x2
# MEM( 17 ) =  0x0
# MEM( 18 ) =  0x1
# MEM( 19 ) =  0xf
# MEM( 20 ) =  0xf
# MEM( 21 ) =  0xf
# MEM( 22 ) =  0xf
# MEM( 23 ) =  0xf
# MEM( 24 ) =  0x5
# MEM( 25 ) =  0x5
# MEM( 26 ) =  0x5
# MEM( 27 ) =  0x5
# MEM( 28 ) =  0x5
# MEM( 29 ) =  0x5
# MEM( 30 ) =  0x5
# MEM( 31 ) =  0x5
# ./tb/tb1  passed OK
