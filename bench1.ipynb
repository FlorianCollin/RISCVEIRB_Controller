# %%
from pynq import Overlay
Proc_RISCV = Overlay('/home/xilinx/pynq/overlays/design_RISCVEIRB/design_RISCVEIRB.bit')
Proc_RISCV?

# %%
RISCV = Proc_RISCV.My_RISCVEIRB_IP_0 
RISCV?

# %%
# Importation de la classe RISCVERIB_Controller et de la fonction charger_fichier
from RISCVEIRB_Controller import *

# %%
# Création d'un instance de la classe RISCVERIB_Controller
Controller = RISCVEIRB_Controller()
# Out:
# new instance of RISCVEIRB_Controller

# %%
mem_inst = charger_fichier(path="./tb/tb1.hex") # Chargement de la mémoire d'instruction pour le testbench 1
Controller.write_inst_mem_from_tab(mem_inst, size=mem_inst.size) # Écrityre de la mémoire d'instructi
# Out:
# Instruction Memory Write Process
#
# Octet value Write for current Instruction 0x528293 at address 0 : [ 0x0 ; 0x52 ; 0x82 ; 0x93 ]
# Octet value Write for current Instruction 0xa30313 at address 1 : [ 0x0 ; 0xa3 ; 0x3 ; 0x13 ]
# Octet value Write for current Instruction 0x6280b3 at address 2 : [ 0x0 ; 0x62 ; 0x80 ; 0xb3 ]
# Octet value Write for current Instruction 0x102023 at address 3 : [ 0x0 ; 0x10 ; 0x20 ; 0x23 ]
# Octet value Write for current Instruction 0x405300b3 at address 4 : [ 0x40 ; 0x53 ; 0x0 ; 0xb3 ]
# Octet value Write for current Instruction 0x102223 at address 5 : [ 0x0 ; 0x10 ; 0x22 ; 0x23 ]
# Octet value Write for current Instruction 0x62c0b3 at address 6 : [ 0x0 ; 0x62 ; 0xc0 ; 0xb3 ]
# Octet value Write for current Instruction 0x102423 at address 7 : [ 0x0 ; 0x10 ; 0x24 ; 0x23 ]
# Octet value Write for current Instruction 0x62e0b3 at address 8 : [ 0x0 ; 0x62 ; 0xe0 ; 0xb3 ]
# ...

# %%
Controller.cpu_execution(log_opt=False)
# Out:
# Program Counter (PC) value :  0 ( 0 ), Current Instruction : 0x528293 , New Address Instruction : 4
# Mem Data Address value :  5 , Data In :  0x0 , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : FetchIns
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  0 ( 0 ), Current Instruction : 0x528293 , New Address Instruction : 4
# Mem Data Address value :  5 , Data In :  0x0 , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : Decode
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  0 ( 0 ), Current Instruction : 0x528293 , New Address Instruction : 4
# Mem Data Address value :  5 , Data In :  0x0 , Data Out: 0x0
# UAL operation:  0b1 -> 1
# Current State Machine is : ExeOpimm
# Data in UT for Load Instruction 0x0 , 0b0
#
# Program Counter (PC) value :  4 ( 1 ), Current Instruction : 0xa30313 , New Address Instruction : 8
# Mem Data Address value :  10 , Data In :  0x0 , Data Out: 0x0
# ...

# %%
Controller.read_data_mem(size=64)
# Out:
# Instruction Memory Read Process
#
# MEM( 0 ) =  0xf
# MEM( 1 ) =  0x5
# MEM( 2 ) =  0xf
# MEM( 3 ) =  0xf
# MEM( 4 ) =  0x0
# MEM( 5 ) =  0x1400
# MEM( 6 ) =  0x0
# MEM( 7 ) =  0x0
# MEM( 8 ) =  0x1
# MEM( 9 ) =  0x1
# MEM( 10 ) =  0x5
# MEM( 11 ) =  0xa
# MEM( 12 ) =  0xf
# MEM( 13 ) =  0x5
# MEM( 14 ) =  0xa
# MEM( 15 ) =  0x2
# MEM( 16 ) =  0x2
# MEM( 17 ) =  0x0
# MEM( 18 ) =  0x1
# MEM( 19 ) =  0xf
# MEM( 20 ) =  0xf
# MEM( 21 ) =  0xf
# MEM( 22 ) =  0xf
# MEM( 23 ) =  0xf
# MEM( 24 ) =  0x5
# MEM( 25 ) =  0x5
# MEM( 26 ) =  0x5
# MEM( 27 ) =  0x5
# MEM( 28 ) =  0x5
# MEM( 29 ) =  0x5
# MEM( 30 ) =  0x5
# MEM( 31 ) =  0x5
# MEM( 32 ) =  0x5
# MEM( 33 ) =  0x0
# MEM( 34 ) =  0x0
# MEM( 35 ) =  0x0
# MEM( 36 ) =  0x0
# MEM( 37 ) =  0x0
# MEM( 38 ) =  0x0
# MEM( 39 ) =  0x0
# MEM( 40 ) =  0x0
# MEM( 41 ) =  0x0
# MEM( 42 ) =  0x0
# MEM( 43 ) =  0x0
# MEM( 44 ) =  0x0
# MEM( 45 ) =  0x0
# MEM( 46 ) =  0x0
# MEM( 47 ) =  0x0
# MEM( 48 ) =  0x0
# MEM( 49 ) =  0x0
# MEM( 50 ) =  0x0
# ...
